# %%
pip install spotipy
# Out:
# ...
#      |████████████████████████████████| 143kB 7.6MB/s
# ...
#      |████████████████████████████████| 71kB 7.3MB/s
# ...
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.26.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
pip install simplejson
# Out:
# ...
#      |████████████████████████████████| 133kB 14.2MB/s
# ...

# %%
import pprint
import sys

import spotipy
import spotipy.util as util
import simplejson as json

# %%
SPOTIPY_CLIENT_ID='f7a43754c96842d0abe4714b5d46b5b8'
SPOTIPY_CLIENT_SECRET='b220dc8a84284d15960df4b2460255ee'
SPOTIPY_REDIRECT_URI=''

# %%
def function():
 #myusername= "uunkdg0z0rrt2ntg16xgi3yk3"
 if len(sys.argv) > 1:
    username = sys.argv[1]
 else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

 scope = 'user-library-read'

 token = util.prompt_for_user_token(
        username=username,
        scope=scope,
        client_id='f7a43754c96842d0abe4714b5d46b5b8',
        client_secret='b220dc8a84284d15960df4b2460255ee',
        redirect_uri=SPOTIPY_REDIRECT_URI)

 if token:
    sp = spotipy.Spotify(auth=token)
    sp.trace = False
    results = sp.current_user_playlists(limit=50)
    for i, item in enumerate(results['items']):
        print("%d %s" %(i, item['name']))
 else:
    print("Can't get token for", username)

# %%
auth_manager=SpotifyClientCredentials(client_id='f7a43754c96842d0abe4714b5d46b5b8',
client_secret='b220dc8a84284d15960df4b2460255ee')

# %%
sp=spotipy.Spotify(auth_manager=auth_manager)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b4c163ac6121> in <module>()
# ----> 1 sp=spotipy.Spotify(auth_manager=auth_manager)
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in __init__(self, auth, requests_session, client_credentials_manager, oauth_manager, auth_manager, proxies, requests_timeout, status_forcelist, retries, status_retries, backoff_factor, language)
#     164         else:
#     165             if requests_session:  # Build a new session.
# --> 166                 self._build_session()
#     167             else:  # Use the Requests API module as a "session".
#     168                 self._session = requests.api
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _build_session(self)
#     198             status=self.status_retries,
#     199             backoff_factor=self.backoff_factor,
# ...

# %%
playlists = sp.user_playlists('mood')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-597abaf3ec89> in <module>()
# ----> 1 playlists = sp.user_playlists('mood')
#       2 while playlists:
#       3     for i, playlist in enumerate(playlists['items']):
#       4         print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
#       5     if playlists['next']:
#
# NameError: name 'sp' is not defined

# %%
scope = 'user-library-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

token = util.prompt_for_user_token(username, scope)

if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_saved_tracks()
    for item in results['items']:
        track = item['track']
        print(track['name'] + ' - ' + track['artists'][0]['name'])
else:
    print("Can't get token for", username)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='f7a43754c96842d0abe4714b5d46b5b8',
 client_secret='b220dc8a84284d15960df4b2460255ee')
sp = sp

playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-aa0ef2ffa6d2> in <module>()
#       1 client_credentials_manager = SpotifyClientCredentials(client_id='f7a43754c96842d0abe4714b5d46b5b8',
#       2  client_secret='b220dc8a84284d15960df4b2460255ee')
# ----> 3 sp = sp
#       4
#       5 playlists = sp.user_playlists('spotify')
#
# NameError: name 'sp' is not defined

# %%
scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

results = sp.current_user_saved_tracks()
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# <ipython-input-17-013eaf7a1b7f> in <module>()
#       1 scope = "user-library-read"
#       2
# ----> 3 sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))
#       4
#       5 results = sp.current_user_saved_tracks()
#
# /usr/local/lib/python3.7/dist-packages/spotipy/oauth2.py in __init__(self, client_id, client_secret, redirect_uri, state, scope, cache_path, username, proxies, show_dialog, requests_session, requests_timeout, open_browser, cache_handler)
#     311         super(SpotifyOAuth, self).__init__(requests_session)
#     312
# --> 313         self.client_id = client_id
#     314         self.client_secret = client_secret
#     315         self.redirect_uri = redirect_uri
#
# /usr/local/lib/python3.7/dist-packages/spotipy/oauth2.py in client_id(self, val)
#      92     @client_id.setter
# ...

# %%
birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id='f7a43754c96842d0abe4714b5d46b5b8',
client_secret='b220dc8a84284d15960df4b2460255ee'))

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-afc871b8e58a> in <module>()
#       1 birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
#       2 spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id='f7a43754c96842d0abe4714b5d46b5b8',
# ----> 3 client_secret='b220dc8a84284d15960df4b2460255ee'))
#       4
#       5 results = spotify.artist_albums(birdy_uri, album_type='album')
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in __init__(self, auth, requests_session, client_credentials_manager, oauth_manager, auth_manager, proxies, requests_timeout, status_forcelist, retries, status_retries, backoff_factor, language)
#     164         else:
#     165             if requests_session:  # Build a new session.
# --> 166                 self._build_session()
# ...
