# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)

# %%
import base64
import requests
import datetime

# %%
client_id='f7a43754c96842d0abe4714b5d46b5b8'
client_secret='b220dc8a84284d15960df4b2460255ee'

# %%
# Do a look up for a token
# This token is for future requests

# %%
client_creds= f"{client_id}:{client_secret}"
type(client_creds)
# Out:
# str

# %%
client_creds_b64= base64.b64encode(client_creds.encode())
print(client_creds_b64)
# Out:
# b'ZjdhNDM3NTRjOTY4NDJkMGFiZTQ3MTRiNWQ0NmI1Yjg6YjIyMGRjOGE4NDI4NGQxNTk2MGRmNGIyNDYwMjU1ZWU='

# %%
token_url = "https://accounts.spotify.com/api/token"
method = "POST"
token_data = {
    "grant_type": "client_credentials"
}
token_headers = {
    "authorization" : f"Basic {client_creds_b64.decode()}"
}
token_header
# Out:
# {'authorization': 'Basic ZjdhNDM3NTRjOTY4NDJkMGFiZTQ3MTRiNWQ0NmI1Yjg6YjIyMGRjOGE4NDI4NGQxNTk2MGRmNGIyNDYwMjU1ZWU='}

# %%
r=requests.post(token_url, data=token_data , headers=token_headers)
print(r.json())
valid_request = r.status_code in range(200, 299)
# Out:
# {'access_token': 'BQAQRnv8TyKiogHlhjbVJFKTm__R_Xp6k7DpYrMnG5St4M94hWE3kivYUvCB9-k2jXcGAq24OozjOrZHkgM', 'token_type': 'Bearer', 'expires_in': 3600}

# %%
if valid_request:
   token_response_data=r.json()
   now = datetime.datetime.now()
   access_token= token_response_data['access_token']
   expires_in = token_response_data['expires_in'] #in seconds
   expires = now + datetime.timedelta(seconds=expires_in)
   did_expire= expires >now
